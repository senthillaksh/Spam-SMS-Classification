# %%
# Importing essential libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
df = pd.read_csv('/content/drive/MyDrive/Spam SMS Classification /spam.csv',encoding = 'latin-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
#Dropping the unnecessary columns

df = df.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'])

# %%
df.rename(columns = {'v1' : 'label', 'v2':'message'}, inplace = True)

# %%
# Mapping values for label
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

# %%
df.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# **Word2vec Implementation**

# %%
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
corpus = []

for i in range(0, len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['message'][i])
    review = review.lower()
    review = review.split()
    
    review = [lemmatizer.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus[0:3]
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply']

# %%
len(corpus)
# Out:
# 5572

# %%
# !pip install gensim==4.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gensim==4.2.0
#   Downloading gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 2.1 MB/s
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.2.0) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim==4.2.0) (1.21.6)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.2.0) (1.7.3)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.2.0

# %%
import gensim

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
gensim.__version__
# Out:
# '4.2.0'

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words[:5]
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply'],
#  ['dun', 'say', 'early', 'hor', 'already', 'say'],
#  ['nah', 'think', 'go', 'usf', 'life', 'around', 'though']]

# %%
len(words)
# Out:
# 5564

# %%
### Lets train Word2vec from scratch
model=gensim.models.Word2Vec(words,window=5,min_count=2)

# %%
model.wv.index_to_key
# Out:
# ['call',
#  'get',
#  'ur',
#  'gt',
#  'lt',
#  'go',
#  'ok',
#  'day',
#  'free',
#  'know',
#  'come',
#  'like',
#  'time',
#  'good',
#  'got',
#  'text',
#  'love',
#  'want',
#  'send',
#  'need',
#  'one',
#  'txt',
#  'today',
#  'going',
#  'home',
#  'stop',
#  'lor',
#  'sorry',
#  'see',
#  'mobile',
#  'still',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'think',
#  'dont',
#  'tell',
#  'week',
#  'phone',
#  'hi',
#  'new',
#  'later',
#  'pls',
#  'please',
#  'co',
#  'msg',
#  'min',
#  'make',
#  'dear',
#  'night',
#  'message',
#  'say',
#  'well',
#  'thing',
#  'much',
#  'claim',
#  'great',
#  'oh',
#  'hope',
#  'hey',
#  'number',
#  'wat',
#  'friend',
#  'happy',
#  'work',
#  'give',
#  'way',
#  'yes',
#  'www',
#  'let',
#  'prize',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'ask',
#  'said',
#  'cash',
#  'win',
#  'yeah',
#  'really',
#  'amp',
#  'life',
#  'babe',
#  'im',
#  'meet',
#  'find',
#  'morning',
#  'uk',
#  'last',
#  'miss',
#  'thanks',
#  'year',
#  'service',
#  'would',
#  'com',
#  'also',
#  'anything',
#  'nokia',
#  'lol',
#  'care',
#  'every',
#  'feel',
#  'keep',
#  'sure',
#  'pick',
#  'contact',
#  'urgent',
#  'sent',
#  'something',
#  'buy',
#  'wait',
#  'cant',
#  'place',
#  'first',
#  'help',
#  'guy',
#  'someone',
#  'even',
#  'nice',
#  'wish',
#  'next',
#  'box',
#  'went',
#  'word',
#  'show',
#  'tonight',
#  'around',
#  'soon',
#  'could',
#  'customer',
#  'money',
#  'many',
#  'sleep',
#  'late',
#  'chat',
#  'per',
#  'sm',
#  'gonna',
#  'ya',
#  'leave',
#  'always',
#  'wan',
#  'name',
#  'dun',
#  'gud',
#  'pm',
#  'lot',
#  'st',
#  'told',
#  'end',
#  'waiting',
#  'hello',
#  'hour',
#  'month',
#  'girl',
#  'fine',
#  'people',
#  'haha',
#  'minute',
#  'heart',
#  'special',
#  'coming',
#  'done',
#  'may',
#  'yet',
#  'thk',
#  'getting',
#  'person',
#  'smile',
#  'th',
#  'guaranteed',
#  'ppm',
#  'use',
#  'try',
#  'best',
#  'thought',
#  'god',
#  'offer',
#  'class',
#  'talk',
#  'holiday',
#  'stuff',
#  'mean',
#  'cost',
#  'live',
#  'car',
#  'man',
#  'lunch',
#  'line',
#  'job',
#  'finish',
#  'draw',
#  'start',
#  'problem',
#  'bit',
#  'plan',
#  'thats',
#  'hr',
#  'better',
#  'meeting',
#  'yup',
#  'never',
#  'trying',
#  'house',
#  'ready',
#  'dat',
#  'ill',
#  'pobox',
#  'cool',
#  'long',
#  'account',
#  'rate',
#  'chance',
#  'mind',
#  'weekend',
#  'game',
#  'real',
#  'latest',
#  'enjoy',
#  'world',
#  'half',
#  'yo',
#  'wk',
#  'play',
#  'check',
#  'sir',
#  'guess',
#  'room',
#  'voucher',
#  'awarded',
#  'lar',
#  'receive',
#  'look',
#  'eat',
#  'camera',
#  'wanna',
#  'nothing',
#  'boy',
#  'pic',
#  'shit',
#  'big',
#  'liao',
#  'another',
#  'sweet',
#  'po',
#  'bt',
#  'dinner',
#  'landline',
#  'ah',
#  'birthday',
#  'jus',
#  'might',
#  'ever',
#  'kiss',
#  'age',
#  'video',
#  'quite',
#  'luv',
#  'xxx',
#  'watch',
#  'watching',
#  'land',
#  'question',
#  'baby',
#  'called',
#  'probably',
#  'pa',
#  'bed',
#  'tv',
#  'nd',
#  'orange',
#  'aight',
#  'early',
#  'thanx',
#  'speak',
#  'worry',
#  'point',
#  'fun',
#  'actually',
#  'maybe',
#  'wont',
#  'hear',
#  'apply',
#  'bus',
#  'two',
#  'bad',
#  'sat',
#  'part',
#  'nite',
#  'ringtone',
#  'network',
#  'remember',
#  'den',
#  'shall',
#  'forgot',
#  'princess',
#  'reach',
#  'dream',
#  'dunno',
#  'code',
#  'easy',
#  'pay',
#  'left',
#  'shopping',
#  'office',
#  'dad',
#  'face',
#  'evening',
#  'hurt',
#  'didnt',
#  'fuck',
#  'dis',
#  'put',
#  'leh',
#  'award',
#  'little',
#  'wife',
#  'thank',
#  'selected',
#  'made',
#  'mate',
#  'yr',
#  'afternoon',
#  'mail',
#  'everything',
#  'true',
#  'looking',
#  'enough',
#  'movie',
#  'sound',
#  'xx',
#  'school',
#  'working',
#  'gift',
#  'anyway',
#  'entry',
#  'detail',
#  'asked',
#  'without',
#  'tmr',
#  'pound',
#  'missing',
#  'town',
#  'collect',
#  'xmas',
#  'wif',
#  'sexy',
#  'valid',
#  'since',
#  'okay',
#  'price',
#  'though',
#  'join',
#  'came',
#  'must',
#  'able',
#  'til',
#  'hav',
#  'missed',
#  'wanted',
#  'mob',
#  'book',
#  'abt',
#  'wot',
#  'important',
#  'run',
#  'answer',
#  'wake',
#  'collection',
#  'lesson',
#  'pain',
#  'bring',
#  'update',
#  'date',
#  'juz',
#  'stay',
#  'test',
#  'de',
#  'charge',
#  'plz',
#  'colour',
#  'decimal',
#  'change',
#  'away',
#  'plus',
#  'till',
#  'weekly',
#  'hair',
#  'double',
#  'havent',
#  'music',
#  'yesterday',
#  'dude',
#  'alright',
#  'wen',
#  'else',
#  'attempt',
#  'saw',
#  'trip',
#  'drink',
#  'food',
#  'credit',
#  'goin',
#  'id',
#  'top',
#  'shop',
#  'haf',
#  'optout',
#  'bored',
#  'online',
#  'lei',
#  'oso',
#  'friendship',
#  'making',
#  'net',
#  'gr',
#  'coz',
#  'national',
#  'driving',
#  'family',
#  'player',
#  'club',
#  'address',
#  'sch',
#  'hot',
#  'feeling',
#  'either',
#  'tried',
#  'delivery',
#  'ard',
#  'ring',
#  'believe',
#  'brother',
#  'wid',
#  'lose',
#  'story',
#  'calling',
#  'second',
#  'nt',
#  'tot',
#  'http',
#  'post',
#  'order',
#  'sae',
#  'mom',
#  'together',
#  'head',
#  'beautiful',
#  'full',
#  'sad',
#  'bonus',
#  'busy',
#  'si',
#  'smoke',
#  'old',
#  'mum',
#  'huh',
#  'await',
#  'row',
#  'close',
#  'saying',
#  'walk',
#  'chikku',
#  'leaving',
#  'info',
#  'set',
#  'poly',
#  'sleeping',
#  'noe',
#  'happen',
#  'eve',
#  'drive',
#  'smiling',
#  'pub',
#  'hand',
#  'email',
#  'parent',
#  'aft',
#  'cause',
#  'awesome',
#  'drop',
#  'match',
#  'news',
#  'rite',
#  'tomo',
#  'started',
#  'private',
#  'finished',
#  'congrats',
#  'simple',
#  'thinking',
#  'hl',
#  'took',
#  'okie',
#  'mths',
#  'suite',
#  'company',
#  'final',
#  'angry',
#  'break',
#  'tc',
#  'everyone',
#  'mine',
#  'content',
#  'wil',
#  'gd',
#  'available',
#  'neva',
#  'card',
#  'unsubscribe',
#  'sister',
#  'tho',
#  'statement',
#  'taking',
#  'auction',
#  'caller',
#  'forget',
#  'reason',
#  'valentine',
#  'worth',
#  'dating',
#  'loving',
#  'found',
#  'anyone',
#  'knw',
#  'search',
#  'gal',
#  'lucky',
#  'touch',
#  'sun',
#  'ticket',
#  'alone',
#  'expires',
#  'whats',
#  'choose',
#  'treat',
#  'type',
#  'carlos',
#  'bank',
#  'open',
#  'fancy',
#  'opt',
#  'whatever',
#  'ltd',
#  'visit',
#  'prob',
#  'party',
#  'secret',
#  'hard',
#  'winner',
#  'college',
#  'frnd',
#  'ha',
#  'smth',
#  'saturday',
#  'anytime',
#  'gone',
#  'song',
#  'exam',
#  'gbp',
#  'decided',
#  'mobileupd',
#  'fast',
#  'far',
#  'welcome',
#  'kind',
#  'friday',
#  'sub',
#  'hit',
#  'happened',
#  'uncle',
#  'identifier',
#  'quiz',
#  'congratulation',
#  'boytoy',
#  'lovely',
#  'wonder',
#  'light',
#  'term',
#  'crazy',
#  'operator',
#  'bout',
#  'hows',
#  'read',
#  'outside',
#  'project',
#  'mu',
#  'camcorder',
#  'nope',
#  'tel',
#  'wit',
#  'chennai',
#  'pretty',
#  'fri',
#  'fucking',
#  'wonderful',
#  'finally',
#  'darlin',
#  'sea',
#  'drug',
#  'goodmorning',
#  'used',
#  'least',
#  'oredi',
#  'wrong',
#  'wkly',
#  'jay',
#  'fr',
#  'blue',
#  'meant',
#  'cum',
#  'fone',
#  'case',
#  'cd',
#  'hold',
#  'ten',
#  'unlimited',
#  'seeing',
#  'wq',
#  'frm',
#  'freemsg',
#  'support',
#  'ni',
#  'course',
#  'savamob',
#  'mrng',
#  'le',
#  'log',
#  'sunday',
#  'hmm',
#  'whole',
#  'frnds',
#  'telling',
#  'listen',
#  'snow',
#  'hungry',
#  'earlier',
#  'gas',
#  'mayb',
#  'sk',
#  'lost',
#  'bslvyl',
#  'eh',
#  'sex',
#  'side',
#  'download',
#  'paper',
#  'computer',
#  'stupid',
#  'mah',
#  'na',
#  'felt',
#  'invited',
#  'die',
#  'cut',
#  'hee',
#  'txts',
#  'understand',
#  'talking',
#  'motorola',
#  'moment',
#  'almost',
#  'currently',
#  'ago',
#  'couple',
#  'pas',
#  'christmas',
#  'etc',
#  'rock',
#  'child',
#  'move',
#  'as',
#  'store',
#  'india',
#  'reading',
#  'area',
#  'joy',
#  'luck',
#  'march',
#  'dnt',
#  'hmmm',
#  'film',
#  'press',
#  'un',
#  'valued',
#  'yar',
#  'tired',
#  'father',
#  'mr',
#  'enter',
#  'within',
#  'happiness',
#  'single',
#  'park',
#  'balance',
#  'john',
#  'met',
#  'redeemed',
#  'charged',
#  'max',
#  'figure',
#  'swing',
#  'nyt',
#  'knew',
#  'bill',
#  'return',
#  'sort',
#  'red',
#  'lady',
#  'ac',
#  'correct',
#  'ipod',
#  'wow',
#  'via',
#  'confirm',
#  'picking',
#  'ugh',
#  'rental',
#  'extra',
#  'darren',
#  'eye',
#  'complimentary',
#  'askd',
#  'information',
#  'surprise',
#  'sending',
#  'promise',
#  'reveal',
#  'kid',
#  'laptop',
#  'difficult',
#  'supposed',
#  'comp',
#  'direct',
#  'shower',
#  'heard',
#  'xy',
#  'load',
#  'hospital',
#  'an',
#  'sell',
#  'grin',
#  'gym',
#  'gotta',
#  'semester',
#  'seen',
#  'photo',
#  'ish',
#  'rent',
#  'slow',
#  'remove',
#  'whenever',
#  'asap',
#  'member',
#  'slowly',
#  'loved',
#  'fantasy',
#  'truth',
#  'blood',
#  'idea',
#  'clean',
#  'discount',
#  'laugh',
#  'door',
#  'train',
#  'asking',
#  'monday',
#  'fact',
#  'rply',
#  'rest',
#  'safe',
#  'hmv',
#  'request',
#  'bcoz',
#  'save',
#  'muz',
#  'reward',
#  'bath',
#  'study',
#  'wine',
#  'wap',
#  'kate',
#  'link',
#  'orchard',
#  'eg',
#  'checking',
#  'comin',
#  'somebody',
#  'police',
#  'usf',
#  'std',
#  'small',
#  'hg',
#  'entered',
#  'ex',
#  'page',
#  'cheer',
#  'abiola',
#  'lover',
#  'loan',
#  'crave',
#  'joke',
#  'txting',
#  'road',
#  'gn',
#  'lovable',
#  'dogging',
#  'wana',
#  'leaf',
#  'empty',
#  'reached',
#  'kick',
#  'deal',
#  'getzed',
#  'water',
#  'bag',
#  'gettin',
#  'teach',
#  'opinion',
#  'woke',
#  'situation',
#  'bathe',
#  'del',
#  'ho',
#  'men',
#  'gave',
#  'sony',
#  'em',
#  'gap',
#  'representative',
#  'pray',
#  'fantastic',
#  'spend',
#  'cheap',
#  'warm',
#  'il',
#  'glad',
#  'doin',
#  'short',
#  'across',
#  'hoping',
#  'wishing',
#  'summer',
#  'admirer',
#  'poor',
#  'convey',
#  'normal',
#  'booked',
#  'wc',
#  'ldn',
#  'somewhere',
#  'mm',
#  'england',
#  'voice',
#  'rd',
#  'ringtones',
#  'doctor',
#  'sale',
#  'copy',
#  'merry',
#  'yep',
#  'custcare',
#  'callertune',
#  'pete',
#  'energy',
#  'immediately',
#  'nah',
#  'bb',
#  'worried',
#  'la',
#  'write',
#  'oops',
#  'cover',
#  'deep',
#  'hw',
#  'otherwise',
#  'catch',
#  'different',
#  'ntt',
#  'med',
#  'usual',
#  'tonite',
#  'cr',
#  'rakhesh',
#  'turn',
#  'mistake',
#  'ge',
#  'nobody',
#  'others',
#  'password',
#  'reaching',
#  'starting',
#  'wondering',
#  'cup',
#  'mon',
#  'bold',
#  'specially',
#  'tht',
#  'pc',
#  'rain',
#  'mode',
#  'bos',
#  'tampa',
#  'seems',
#  'bx',
#  'flight',
#  'decide',
#  'user',
#  'charity',
#  'ice',
#  'comuk',
#  'bid',
#  'norm',
#  'sick',
#  'gay',
#  'excellent',
#  'ip',
#  'seriously',
#  'forever',
#  'hiya',
#  'possible',
#  'fall',
#  'digital',
#  'stand',
#  'add',
#  'forwarded',
#  'sunshine',
#  'colleague',
#  'street',
#  'result',
#  'disturb',
#  'style',
#  'ldew',
#  'sofa',
#  'goodnight',
#  'meh',
#  'near',
#  'kinda',
#  'silent',
#  'ive',
#  'mrt',
#  'dead',
#  'using',
#  'trust',
#  'studying',
#  'flag',
#  'unless',
#  'moral',
#  'rcvd',
#  'reference',
#  'brings',
#  'weed',
#  'urself',
#  'excuse',
#  'round',
#  'thinkin',
#  'access',
#  'rose',
#  'al',
#  'none',
#  'cake',
#  'sitting',
#  'logo',
#  'accept',
#  'sport',
#  'especially',
#  'doesnt',
#  'staying',
#  'indian',
#  'lect',
#  'ending',
#  'buying',
#  'bluetooth',
#  'completely',
#  'hotel',
#  'lazy',
#  'noon',
#  'cancel',
#  'fullonsms',
#  'awaiting',
#  'entitled',
#  'black',
#  'power',
#  'ar',
#  'anymore',
#  'record',
#  'yahoo',
#  'ad',
#  'aha',
#  'funny',
#  'team',
#  'ave',
#  'giving',
#  'medical',
#  'umma',
#  'weight',
#  'cute',
#  'woman',
#  ...]

# %%
model.corpus_count
# Out:
# 5564

# %%
model.epochs
# Out:
# 5

# %%
model.wv['happy']
# Out:
# array([-0.2713956 ,  0.37075973,  0.0777479 , -0.04176151,  0.06369221,
#        -0.65240175,  0.17004082,  0.851472  , -0.33863044, -0.20195194,
#        -0.08830331, -0.7275222 ,  0.02598781,  0.13217232,  0.01989976,
#        -0.3589851 ,  0.08357856, -0.5146917 , -0.07616074, -0.77935994,
#         0.23344304,  0.17939019,  0.18740985, -0.19669293, -0.09294482,
#         0.07704623, -0.26087353, -0.34317788, -0.3959698 ,  0.10268014,
#         0.43425098,  0.1809799 ,  0.06065208, -0.32193708, -0.21377519,
#         0.46145853, -0.07536908, -0.40328816, -0.19523354, -0.6660124 ,
#        -0.00635151, -0.4423179 , -0.03175237, -0.00220347,  0.36297065,
#        -0.08566655, -0.21293646,  0.01934019,  0.21758614,  0.27971673,
#         0.28838566, -0.37464115, -0.14489618, -0.05122625, -0.29655004,
#         0.26109013,  0.257742  , -0.04463259, -0.47127527,  0.17396301,
#         0.14960594,  0.07193516, -0.15318349, -0.03609819, -0.5039696 ,
#         0.31984326,  0.28289917,  0.28357828, -0.52504206,  0.54474854,
#        -0.21072051,  0.30289665,  0.5079563 , -0.1396662 ,  0.46092033,
#         0.3069535 , -0.02799161, -0.10609763, -0.28325772,  0.21590033,
#        -0.16979492,  0.11809344, -0.30386207,  0.54673886, -0.10484773,
#        -0.05859083, -0.04964272,  0.5064971 ,  0.4890923 ,  0.21576567,
#         0.6168459 ,  0.21649788, -0.12619184,  0.2517933 ,  0.54000384,
#         0.31677422,  0.17703295, -0.47875547,  0.21173833, -0.07346745],
#       dtype=float32)

# %%
model.wv.similar_by_word('happy')
# Out:
# [('day', 0.9995060563087463),
#  ('dear', 0.9994257092475891),
#  ('hope', 0.9993958473205566),
#  ('year', 0.999374270439148),
#  ('new', 0.9993714094161987),
#  ('life', 0.9993177652359009),
#  ('well', 0.9993089437484741),
#  ('love', 0.99930739402771),
#  ('get', 0.9993012547492981),
#  ('great', 0.9992979764938354)]

# %%
model.wv['happy'].shape
# Out:
# (100,)

# %%
res = np.mean([model.wv[word] for word in words[3] if word in model.wv.index_to_key],axis=0)

# %%
res
# Out:
# array([-0.20295642,  0.29536685,  0.06252173, -0.03695216,  0.03485707,
#        -0.49734306,  0.13774483,  0.6576825 , -0.25406206, -0.13621952,
#        -0.07359572, -0.54961044,  0.02115541,  0.0983358 , -0.00873029,
#        -0.27251667,  0.06753393, -0.40919042, -0.05192734, -0.61787343,
#         0.1873209 ,  0.14304511,  0.16152559, -0.14778782, -0.08479015,
#         0.06905388, -0.19894056, -0.25778115, -0.2895775 ,  0.07685545,
#         0.3516921 ,  0.12751076,  0.05990427, -0.24140133, -0.15476094,
#         0.3603778 , -0.04192321, -0.30475807, -0.13931711, -0.51496655,
#        -0.0083744 , -0.3434653 , -0.0342137 ,  0.00739776,  0.29083696,
#        -0.06926309, -0.17147155,  0.01208111,  0.17118402,  0.20491101,
#         0.21721633, -0.27785662, -0.12071434, -0.03545009, -0.20526344,
#         0.21085973,  0.20780756, -0.03845368, -0.36420253,  0.11369876,
#         0.10937617,  0.05864052, -0.11132834, -0.01580675, -0.40601218,
#         0.23407525,  0.23132034,  0.21471743, -0.41889572,  0.4271957 ,
#        -0.15470514,  0.23568034,  0.4010439 , -0.10018667,  0.35118613,
#         0.25754592, -0.01893891, -0.09186604, -0.2343489 ,  0.18252765,
#        -0.12651943,  0.0895457 , -0.23222125,  0.42587307, -0.08174638,
#        -0.05714126, -0.03853768,  0.3890992 ,  0.3672959 ,  0.1767711 ,
#         0.47068584,  0.1743905 , -0.0925701 ,  0.18787587,  0.431078  ,
#         0.233702  ,  0.13209552, -0.3517951 ,  0.1600425 , -0.05896578],
#       dtype=float32)

# %%
res.dtype
# Out:
# dtype('float32')

# %%
type(res)
# Out:
# numpy.ndarray

# %%
def avg_word2vec(doc):
  return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)

# %%
type(model.wv.index_to_key)
# Out:
# list

# %%
words[3]
# Out:
# ['dun', 'say', 'early', 'hor', 'already', 'say']

# %%
#apply for the entire sentences
X=[]
for i in range(len(words)):
    X.append(avg_word2vec(words[i]))

# %%
X[3]
# Out:
# array([-0.20295642,  0.29536685,  0.06252173, -0.03695216,  0.03485707,
#        -0.49734306,  0.13774483,  0.6576825 , -0.25406206, -0.13621952,
#        -0.07359572, -0.54961044,  0.02115541,  0.0983358 , -0.00873029,
#        -0.27251667,  0.06753393, -0.40919042, -0.05192734, -0.61787343,
#         0.1873209 ,  0.14304511,  0.16152559, -0.14778782, -0.08479015,
#         0.06905388, -0.19894056, -0.25778115, -0.2895775 ,  0.07685545,
#         0.3516921 ,  0.12751076,  0.05990427, -0.24140133, -0.15476094,
#         0.3603778 , -0.04192321, -0.30475807, -0.13931711, -0.51496655,
#        -0.0083744 , -0.3434653 , -0.0342137 ,  0.00739776,  0.29083696,
#        -0.06926309, -0.17147155,  0.01208111,  0.17118402,  0.20491101,
#         0.21721633, -0.27785662, -0.12071434, -0.03545009, -0.20526344,
#         0.21085973,  0.20780756, -0.03845368, -0.36420253,  0.11369876,
#         0.10937617,  0.05864052, -0.11132834, -0.01580675, -0.40601218,
#         0.23407525,  0.23132034,  0.21471743, -0.41889572,  0.4271957 ,
#        -0.15470514,  0.23568034,  0.4010439 , -0.10018667,  0.35118613,
#         0.25754592, -0.01893891, -0.09186604, -0.2343489 ,  0.18252765,
#        -0.12651943,  0.0895457 , -0.23222125,  0.42587307, -0.08174638,
#        -0.05714126, -0.03853768,  0.3890992 ,  0.3672959 ,  0.1767711 ,
#         0.47068584,  0.1743905 , -0.0925701 ,  0.18787587,  0.431078  ,
#         0.233702  ,  0.13209552, -0.3517951 ,  0.1600425 , -0.05896578],
#       dtype=float32)

# %%
type(X)
# Out:
# list

# %%
len(X)
# Out:
# 5564

# %%
X_new = np.array(X)

# %%
words[3]
# Out:
# ['dun', 'say', 'early', 'hor', 'already', 'say']

# %%
X_new[3]
# Out:
# array([-0.20295642,  0.29536685,  0.06252173, -0.03695216,  0.03485707,
#        -0.49734306,  0.13774483,  0.6576825 , -0.25406206, -0.13621952,
#        -0.07359572, -0.54961044,  0.02115541,  0.0983358 , -0.00873029,
#        -0.27251667,  0.06753393, -0.40919042, -0.05192734, -0.61787343,
#         0.1873209 ,  0.14304511,  0.16152559, -0.14778782, -0.08479015,
#         0.06905388, -0.19894056, -0.25778115, -0.2895775 ,  0.07685545,
#         0.3516921 ,  0.12751076,  0.05990427, -0.24140133, -0.15476094,
#         0.3603778 , -0.04192321, -0.30475807, -0.13931711, -0.51496655,
#        -0.0083744 , -0.3434653 , -0.0342137 ,  0.00739776,  0.29083696,
#        -0.06926309, -0.17147155,  0.01208111,  0.17118402,  0.20491101,
#         0.21721633, -0.27785662, -0.12071434, -0.03545009, -0.20526344,
#         0.21085973,  0.20780756, -0.03845368, -0.36420253,  0.11369876,
#         0.10937617,  0.05864052, -0.11132834, -0.01580675, -0.40601218,
#         0.23407525,  0.23132034,  0.21471743, -0.41889572,  0.4271957 ,
#        -0.15470514,  0.23568034,  0.4010439 , -0.10018667,  0.35118613,
#         0.25754592, -0.01893891, -0.09186604, -0.2343489 ,  0.18252765,
#        -0.12651943,  0.0895457 , -0.23222125,  0.42587307, -0.08174638,
#        -0.05714126, -0.03853768,  0.3890992 ,  0.3672959 ,  0.1767711 ,
#         0.47068584,  0.1743905 , -0.0925701 ,  0.18787587,  0.431078  ,
#         0.233702  ,  0.13209552, -0.3517951 ,  0.1600425 , -0.05896578],
#       dtype=float32)

# %%
corpus[:3]
# Out:
# ['go jurong point crazy available bugis n great world la e buffet cine got amore wat',
#  'ok lar joking wif u oni',
#  'free entry wkly comp win fa cup final tkts st may text fa receive entry question std txt rate c apply']

# %%
y = df[list(map(lambda x: len(x)>0, corpus))]
y.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
y = y['label']
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
y.shape
# Out:
# (5564,)

# %%
# Train Test Split

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size = 0.20, random_state = 0)
